# %% [markdown]
# # Fantasy Football Prep
#
# The League I'm in has the following parameters:
# 1. 1 QB
# 2. 2 RB
# 3. 3 WR
# 4. 1 TE
# 5. 1 flex
# 6. 1 D/ST
# 7. 1 K
#
# The goal of this notebook is to provide draft-day assistance by interfacing with fantasy pro's aggregation of rankings and draft statistics.

# %%
# what should the flex position be filled with?
flex = 'RB'

roster = ['QB','RB','RB','WR','WR','WR','TE',flex,'DST','K']

def check_roster(open_roster,rules):
    
    # do a uniqueness check?

# %%
# boilerplate imports

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

import matplotlib as mpl
cmap = cm.gnuplot

# %%
# imports for scraping

from bs4 import BeautifulSoup

import requests

import operator

# %% [markdown]
# ## Basic Application: Kicker Rankings

# %%
r  = requests.get('https://www.fantasypros.com/nfl/rankings/half-point-ppr-cheatsheets.php')

# standard league
#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10

data = r.text; soup = BeautifulSoup(data); tables = soup.findAll('table')

for indx,table in enumerate(tables): 
       
    if indx==0:
                
        for row in table.find_all("tr")[2:]:
            sav = [td.get_text() for td in row.find_all("td")]
            
            try:
                if sav[2][0] == 'K':
                    #print sav[2][0:1]
                    print sav[0],sav[1]
                elif sav[2][0] == 'D':
                    
                    #print sav[2][0:3]
                    pass
                else:
                    #print sav[2][0:2]
                    pass
                
            except:
                pass
# Out:
# 174 Justin Tucker BAL
# 175 Stephen Gostkowski NE
# 190 Dan Bailey DAL
# 197 Matt Bryant ATL
# 200 Mason Crosby GB
# 217 Adam Vinatieri IND
# 224 Steven Hauschka BUF
# 242 Matt Prater DET
# 248 Cairo Santos KC
# 249 Chandler Catanzaro NYJ
# 250 Brandon McManus DEN
# 251 Sebastian Janikowski OAK
# 256 Chris Boswell PIT
# 262 Will Lutz NO
# 264 Graham Gano CAR
# 273 Dustin Hopkins WAS
# 290 Mike Nugent NYG
# 291 Roberto Aguayo CHI
# 301 Nick Folk TB
# 302 Josh Lambo LAC
# 310 Nick Novak HOU
# 322 Ryan Succop TEN
# 327 Phil Dawson ARI
# 329 Blair Walsh SEA
# 330 Caleb Sturgis PHI
# 394 Kai Forbath MIN
# 396 Josh Brown FA
# 398 Aldrick Rosas NYG
# 399 Dan Carpenter FA
# 401 Jake Elliott CIN
# 402 Jason Myers JAC
# 403 Greg Zuerlein LAR
# 404 Zane Gonzalez CLE
# 406 Harrison Butker CAR
# 407 Robbie Gould SF
# 408 Connor Barth CHI
# 409 Andrew Franks MIA

# %%
r  = requests.get('https://www.fantasypros.com/nfl/rankings/half-point-ppr-cheatsheets.php')

# standard league
#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10

data = r.text; soup = BeautifulSoup(data); tables = soup.findAll('table')

for indx,table in enumerate(tables): 
       
    if indx==0:
                
        for row in table.find_all("tr")[2:]:
            sav = [td.get_text() for td in row.find_all("td")]
            
            try:
                if sav[2][0] == 'K':
                    
                    #print sav[2][0:1]
                    pass
                elif sav[2][0] == 'D':
                    
                    #print sav[2][0:3]
                    #print sav[0],sav[1]


                    pass
                
                elif sav[2][0] =='W':
                    print sav[0],sav[1]
                
                else:
                    #print sav[2][0:2]
                    pass
                
            except:
                pass
# Out:
# 3 Antonio Brown PIT
# 4 Odell Beckham Jr. NYG
# 5 Julio Jones ATL
# 8 A.J. Green CIN
# 9 Mike Evans TB
# 11 Jordy Nelson GB
# 15 Michael Thomas NO
# 16 Dez Bryant DAL
# 18 T.Y. Hilton IND
# 19 Doug Baldwin SEA
# 20 Amari Cooper OAK
# 22 Brandin Cooks NE
# 25 DeAndre Hopkins HOU
# 26 Demaryius Thomas DEN
# 30 Keenan Allen LAC
# 32 Terrelle Pryor WAS
# 33 Alshon Jeffery PHI
# 34 Allen Robinson JAC
# 37 Davante Adams GB
# 40 Michael Crabtree OAK
# 43 Golden Tate DET
# 46 Larry Fitzgerald ARI
# 49 Sammy Watkins LAR
# 51 Jarvis Landry MIA
# 53 Tyreek Hill KC
# 55 Emmanuel Sanders DEN
# 57 Julian Edelman NE
# 59 Martavis Bryant PIT
# 61 Jamison Crowder WAS
# 62 Stefon Diggs MIN
# 67 Kelvin Benjamin CAR
# 68 Willie Snead NO
# 73 Brandon Marshall NYG
# 76 Pierre Garcon SF
# 77 Donte Moncrief IND
# 82 DeSean Jackson TB
# 85 Jeremy Maclin BAL
# 87 Devante Parker MIA
# 90 Eric Decker TEN
# 91 Cameron Meredith CHI
# 93 Tyrell Williams LAC
# 101 Kenny Britt CLE
# 105 Randall Cobb GB
# 106 Jordan Matthews BUF
# 111 Adam Thielen MIN
# 113 Mike Wallace BAL
# 117 Corey Coleman CLE
# 118 Rishard Matthews TEN
# 120 John Brown ARI
# 121 Corey Davis TEN
# 125 Marvin Jones DET
# 133 Ted Ginn NO
# 137 Sterling Shepard NYG
# 139 Zay Jones BUF
# 145 Josh Doctson WAS
# 148 Tyler Lockett SEA
# 151 Robby Anderson NYJ
# 152 Kevin White CHI
# 155 Cole Beasley DAL
# 158 Kenny Stills MIA
# 161 Breshad Perriman BAL
# 167 Kenny Golladay DET
# 171 Marqise Lee JAC
# 173 Robert Woods LAR
# 176 J.J. Nelson ARI
# 178 Taylor Gabriel ATL
# 179 John Ross CIN
# 184 Allen Hurns JAC
# 187 Cooper Kupp LAR
# 192 Devin Funchess CAR
# 196 Mohamed Sanu ATL
# 199 Nelson Agholor PHI
# 202 Tavon Austin LAR
# 203 Mike Williams LAC
# 212 Chris Conley KC
# 213 Torrey Smith PHI
# 214 Paul Richardson SEA
# 216 Will Fuller HOU
# 221 Malcolm Mitchell NE
# 226 Jaron Brown ARI
# 228 Tyler Boyd CIN
# 230 Brandon LaFell CIN
# 234 Braxton Miller HOU
# 239 Chris Hogan NE
# 243 Terrance Williams DAL
# 245 Laquon Treadwell MIN
# 246 Eli Rogers PIT
# 253 Curtis Samuel CAR
# 255 Travis Benjamin LAC
# 259 ArDarius Stewart NYJ
# 261 JuJu Smith-Schuster PIT
# 269 Michael Floyd MIN
# 270 Kendall Wright CHI
# 272 Marquise Goodwin SF
# 274 Dontrelle Inman LAC
# 284 Russell Shepard CAR
# 285 Jeremy Kerley SF
# 296 Seth Roberts OAK
# 297 Charone Peake NYJ
# 303 Chester Rogers IND
# 307 Albert Wilson KC
# 311 Tajae Sharpe TEN
# 312 Andre Holmes BUF
# 321 Jaelen Strong HOU
# 325 Kamar Aiken IND
# 328 Carlos Henderson DEN
# 331 Dede Westbrook JAC
# 332 Josh Gordon CLE
# 334 Phillip Dorsett IND
# 336 Chris Godwin TB
# 337 Geronimo Allison GB
# 341 Chad Williams ARI
# 342 Bruce Ellington HOU
# 346 Brandon Coleman NO
# 347 Leonte Carroo MIA
# 349 Demarcus Robinson KC
# 350 Taywan Taylor TEN
# 352 Aldrick Robinson SF
# 353 Jermaine Kearse SEA
# 356 Markus Wheaton CHI
# 357 Vincent Jackson FA
# 358 Sammie Coates PIT
# 359 Brian Quick WAS
# 363 Josh Reynolds LAR
# 368 Victor Cruz CHI
# 373 Wendall Williams HOU
# 374 Ryan Switzer DAL
# 376 Rashard Higgins CLE
# 381 Adam Humphries TB
# 384 Dorial Green-Beckham FA
# 389 Cordarrelle Patterson OAK
# 393 Amara Darboh SEA

# %%
def calculate_snake(pos,rounds=12,teams=12):
    double = [pos,float(teams)+1.-pos]
    order = []
    for rnd in range(0,rounds,2):
        order.extend(double)
        
    return float(teams)*(np.arange(0.,float(rounds),1.)) + np.array(order)

# %%
r  = requests.get('https://www.fantasypros.com/nfl/rankings/half-point-ppr-cheatsheets.php')

# standard league
#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10


data = r.text

soup = BeautifulSoup(data)

tables = soup.findAll('table')

ordering = calculate_snake(3.)

ordinal = 6

listing = []
player = []
position = []
notes = []
for indx,table in enumerate(tables): 
    
    #print indx,[th.get_text() for th in table.find("tr").find_all("th")]
   
    if indx==0:
        
        #print [th.get_text() for th in table.find("tr").find_all("th")]
        
        for row in table.find_all("tr")[1:]:
            sav = [td.get_text() for td in row.find_all("td")]
            # get the links here and then think about scraping those pages
            
            #try:
            #    sav2 = [td.find('a') for td in row.find_all("td")][1]
            #    print 'https://www.fantasypros.com'+sav2.get('href')
            #except:
            #    pass
            
            try:
                #if float(sav[0]) in ordering:
                #    print sav[0],sav[1],sav[2]#,sav[10]
                listing.append(float(sav[ordinal]))
                player.append(sav[1])
                position.append(sav[2])
                notes.append(sav[10])
                
            except:
                pass#print 'fail'
                
            
NU = np.array(listing)
PL = np.array(player)
PO = np.array(position)
NO = np.array(notes)
# organize as specified
reorg = NU.argsort()
                    
for entry,value in enumerate(NU[reorg]):
    
    if (float(entry) + 1.) in ordering:
        print NU[reorg[entry]],PL[reorg[entry]],PO[reorg[entry]]
        print ''
        print NO[reorg[entry]]
        print ''
        


#https://www.fantasypros.com/nfl/players/david-johnson-rb.php

# replace 'players' with 'stats'
# Out:
# 3.1 Antonio Brown PIT  WR1
#
# It's now four straight seasons where Brown has finished as a top-seven wide receiver, including two seasons as the No. 1 receiver. He's averaged 1,579 yards and 10.8 touchdowns in that span, and keep in mind that he posted his two best seasons while Martavis Bryant was on the field with him.
#
# 26.3 Brandin Cooks NE  WR12
#
# Cooks was the #8 receiver in football last season with Drew Brees, and while the Patriots do have more weapons to spread the ball around to, they still have Tom Brady so Cooks should once again be a WR1.
#
# 27.9 Isaiah Crowell CLE  RB12
#
# What do you get when you mix an average running back with a great offensive line? An RB2, that's Crowell in a nutshell. Most point to his yards per carry (4.8) being great last year, but he totaled 48 percent of his rushing yards on just 16 carries. Their offensive line may just be the best in the NFL at this point, making him an intriguing option.
#
# 47.4 Larry Fitzgerald ARI  WR22
#
# Entering what is likely his last NFL season, Fitzgerald has now put up back-to-back 1,000-yard seasons with Carson Palmer behind center. They added Chad Williams via the draft, but he needs time to develop. The only competition he has for targets over the middle of the field is David Johnson. Fitzgerald was also sixth in redzone targets last year with 23 of them.
#
# 53.5 Jarvis Landry MIA  WR24
#
# Surely lower than most, I'm expecting Devante Parker to take a step forward in 2017. After averaging nine targets per game over the first 36 games of his career, Landry averaged just 7.1 targets over the final 12 games under Adam Gase. He's somewhat safe in PPR leagues, but there's not a whole lot of upside here.
#
# 72.7 Mike Gillislee NE  RB28
#
# The Patriots ran the ball more often inside the 5-yard line than any other team in the NFL and it wasn't even close. Blount was among the worst RBs in terms of yards per carry, Gillislee was the single best. Gillislee has also been the best at converting goal line carries over the past two seasons. He could be in for a huge season if Belichek puts the ball in his hands enough.
#
# 77.7 Kyle Rudolph MIN  TE7
#
# People left the bandwagon too early on him, myself included. But when you see the chemistry between him and Sam Bradford, you should be buying in. He saw a position-high 132 targets last year, including 8.7 per game once offensive coordinator Pat Shurmer took over. Keep in mind that he finished as the No. 3 tight end, while both Adam Thielen and Stefon Diggs got theirs.
#
# 94.7 Eddie Lacy SEA  RB33
#
# There is a lot to worry about with Lacy: the Seahawks offensive line is the worst in the league, Lacy has weight issues and CJ Prosise is just one of several backs vying for touches behind him. What it all comes down to, however, is that Lacy is among the most talented
#
# 99.7 Robert Kelley WAS  RB36
#
# Most remember Kelley for his Monday night performance against the Packers in Week 11 where he finished with 137 yards and three touchdowns, but they must've missed what ensued after that game. In the final six games of the season, Kelley averaged just 3.33 yards per carry on 84 carries with two touchdowns. He averaged just 8.05 fantasy points per game in that stretch, leading the Redskins to go out and snag Samaje Perine in the NFL Draft. You shouldn't bet on him to retain the starting job for very long, as he can only contribute on first and second down, making the offense predictable.
#
# 116.5 Andy Dalton CIN  QB16
#
# Most don't know that Dalton has finished as a top-12 fantasy quarterback in three of the last five years, including a No. 4 finish in 2013. He's got some issues on the offensive line, but he also has the best receiving options he's ever had, and it's really not all that close.
#
# 125.6 Tyrod Taylor BUF  QB18
#
# Finished as the QB7 on a point per game basis in 2016, and was after finishing as the QB8 in 2015. He continues to be one of the most under-appreciated players in all of fantasy. The Bills went out and spent a high-2nd-round pick in order to snag wide receiver Zay Jones, signed free agent Anquan Boldin, and traded for Jordan Matthews. This is all negated, of course, by the fact that they traded away his true No. 1 wide receiver in Sammy Watkins. Taylor has only averaged one fewer fantasy point per game without Watkins playing, though it's not the largest of sample sizes. Losing Watkins really hurts.
#
# 147.0 Seattle Seahawks  DST2
#
# Seattle has been losing pieces in order to stay under the cap, but they are still loaded with talent and some of the best playmakers on the defensive side of the ball in all of football. Consider them a top 3 defense once again.

# %%
r  = requests.get('https://www.fantasypros.com/nfl/players/tom-brady.php')

# standard league
#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10


data = r.text

soup = BeautifulSoup(data)

tables = soup.findAll('table')

for indx,table in enumerate(tables): 
    
    print indx,[th.get_text() for th in table.find("tr").find_all("th")]
    
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Rushing Stats']:
        
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Receiving Stats']:
        
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Passing Stats']:



        #print [th.get_text() for th in table.find("tr").find_all("th")]
        
    for row in table.find_all("tr")[1:]:
            sav = [td.get_text() for td in row.find_all("td")]
            
            print sav
   

# receiving
# SEASON	TEAM	GAMES	REC	TGT	YDS	Y/R	LG	TD

# rushing 
# SEASON	TEAM	GAMES	ATT	YDS	Y/A	LG	TD	FUM	FUML
# Out:
# 0 []
# 1 [u' ', u'ECR', u'Best', u'Worst', u'# of Experts']
# [u'Draft', u'QB #2', u'QB #1', u'QB #8', u'104']
# [u'Dynasty ', u'QB #10', u'QB #6', u'QB #18', u'21']
# 2 [u' ', u'Consensus', u'CBS', u'Fantrax', u'NFL', u'DW', u'FFC']
# [u'Overall', u'#17', u'#14', u'#23', u'#23', u'#24', u'#30']
# [u'Quarterbacks', u'#2', u'#2', u'#2', u'#2', u'#2', u'#2']
# 3 [u'Pass Cmp', u'Pass Att', u'Pass Yds', u'Pass Tds', u'Pass Ints', u'Rush Att', u'Rush Yds', u'Rush Tds', u'Fumbles', u'Points']
# [u'393.4', u'601.8', u'4697.4', u'35.4', u'8.3', u'35.5', u'85.3', u'1.3', u'2.8', u'323.9']
# 4 [u' ', u'Pass Yds', u'Pass Tds', u'Rush Yds', u'Rush Tds', u'Points']
# [u'Last Week', u'276', u'3', u'6', u'0', u'25.6']
# [u'Last 3 Weeks', u'226', u'2', u'1.7', u'0', u'17.9']
# [u'Season to Date', u'296.2', u'2.3', u'5.3', u'0', u'21.5']
# 5 [u' ', u'OPP', u'Pass Yds', u'Pass Tds', u'Rush Yds', u'Rush Tds', u'Points']
# [u'Week 17', u'@ MIA', u'276', u'3', u'6', u'0', u'25.6']
# [u'Week 16', u'vs. NYJ', u'214', u'3', u'0', u'0', u'20.6']
# [u'Week 15', u'@ DEN', u'188', u'0', u'-1', u'0', u'7.4']
# [u'Week 14', u'vs. BAL', u'406', u'3', u'-1', u'0', u'26.1']
# 6 [u' ', u'Opp', u'Summary']
# [u'Next Game', u'vs. KC', u'25th easiest opponent']
# [u'Next 3 Games', u'NO, HOU, CAR', u'18th easiest opponents']
# [u'Playoffs (?)', u'MIA, PIT, BUF', u'17th easiest opponents']
# [u'Rest of Season', u'--', u'16th easiest remaining opponents']
# 7 []
# 8 []
# 9 []
# 10 []
# 11 []
# [u'T-1.', u'Jason Moore', u'QB #2']
# [u'T-3.', u'Derek Lofland', u'QB #5']
# [u'T-3.', u'Justin Boone', u'QB #2']
# [u'T-3.', u'Kevin English', u'-']
# [u'View Overall Accuracy Rankings']
# 12 []
# [u'2', u"Le'Veon Bell (PIT)", u'RB']
# [u'3', u'Antonio Brown (PIT)', u'WR']
# [u'4', u'Odell Beckham Jr. (NYG)', u'WR']
# [u'5', u'Julio Jones (ATL)', u'WR']
# [u'6', u'LeSean McCoy (BUF)', u'RB']
# [u'7', u'Melvin Gordon (LAC)', u'RB']
# [u'8', u'Mike Evans (TB)', u'WR']
# [u'9', u'A.J. Green (CIN)', u'WR']
# [u'10', u'Devonta Freeman (ATL)', u'RB']
# [u'\xa0', u'View All Rankings', u'\xa0']
# 13 []
# [u'12', u'Jay Ajayi (MIA)', u'RB']
# [u'13', u'Jordan Howard (CHI)', u'RB']
# [u'14', u'DeMarco Murray (TEN)', u'RB']
# [u'15', u'Michael Thomas (NO)', u'WR']
# [u'16', u'Dez Bryant (DAL)', u'WR']
# [u'17', u'Todd Gurley (LAR)', u'RB']
# [u'18', u'T.Y. Hilton (IND)', u'WR']
# [u'19', u'Leonard Fournette (JAC)', u'RB']
# [u'20', u'Amari Cooper (OAK)', u'WR']
# 14 []
# [u'22', u'Doug Baldwin (SEA)', u'WR']
# [u'23', u'Rob Gronkowski (NE)', u'TE']
# [u'24', u'Isaiah Crowell (CLE)', u'RB']
# [u'25', u'Lamar Miller (HOU)', u'RB']
# [u'26', u'Brandin Cooks (NE)', u'WR']
# [u'27', u'DeAndre Hopkins (HOU)', u'WR']
# [u'28', u'Demaryius Thomas (DEN)', u'WR']
# [u'29', u'Marshawn Lynch (OAK)', u'RB']
# [u'30', u'Carlos Hyde (SF)', u'RB']
# 15 []
# [u'2', u'Paul Goldschmidt (ARI)', u'1B']
# [u'3', u'Jose Altuve (HOU)', u'2B']
# [u'4', u'Nolan Arenado (COL)', u'3B']
# [u'5', u'Charlie Blackmon (COL)', u'CF']
# [u'6', u'Chris Sale (BOS)', u'SP']
# [u'7', u'Max Scherzer (WSH)', u'SP']
# [u'8', u'Giancarlo Stanton (MIA)', u'RF']
# [u'9', u'Joey Votto (CIN)', u'1B']
# [u'10', u'Kris Bryant (CHC)', u'1B,3B']
# [u'\xa0', u'View All Rankings', u'\xa0']
# 16 []
# [u'12', u'Mookie Betts (BOS)', u'RF']
# [u'13', u'Corey Kluber (CLE)', u'SP']
# [u'14', u'Freddie Freeman (ATL)', u'1B,3B']
# [u'15', u'Corey Seager (LAD)', u'SS']
# [u'16', u'Anthony Rizzo (CHC)', u'1B,2B']
# [u'17', u'George Springer (HOU)', u'CF,RF']
# [u'18', u'Nelson Cruz (SEA)', u'RF,DH']
# [u'19', u'Francisco Lindor (CLE)', u'SS']
# [u'20', u'Daniel Murphy (WSH)', u'1B,2B']
# 17 []
# [u'22', u'J.D. Martinez (ARI)', u'RF']
# [u'23', u'Edwin Encarnacion (CLE)', u'1B,DH']
# [u'24', u'Aaron Judge (NYY)', u'RF,DH']
# [u'25', u'Jose Abreu (CWS)', u'1B,DH']
# [u'26', u'Robinson Cano (SEA)', u'2B']
# [u'27', u'Cody Bellinger (LAD)', u'1B,LF']
# [u'28', u'Jose Ramirez (CLE)', u'2B,3B']
# [u'29', u'Yu Darvish (LAD)', u'SP']
# [u'30', u'Miguel Cabrera (DET)', u'1B,DH']
# 18 []
# [u'2', u'James Harden (HOU)', u'PG,SG']
# [u'3', u'Stephen Curry (GSW)', u'PG,SG']
# [u'4', u'Kevin Durant (GSW)', u'SF,PF']
# [u'5', u'Karl-Anthony Towns (MIN)', u'C']
# [u'6', u'Anthony Davis (NOR)', u'PF,C']
# [u'7', u'LeBron James (CLE)', u'SF,PF']
# [u'8', u'Chris Paul (HOU)', u'PG']
# [u'9', u'Kawhi Leonard (SAS)', u'SG,SF']
# [u'10', u'DeMarcus Cousins (NOR)', u'PF,C']
# [u'\xa0', u'View All Rankings', u'\xa0']
# 19 []
# [u'12', u'Paul George (OKC)', u'SF,PF']
# [u'13', u'Hassan Whiteside (MIA)', u'C,PF']
# [u'14', u'Damian Lillard (POR)', u'PG']
# [u'15', u'John Wall (WAS)', u'PG']
# [u'16', u'Kyle Lowry (TOR)', u'PG']
# [u'17', u'Paul Millsap (DEN)', u'PF,C']
# [u'18', u'Jimmy Butler (MIN)', u'SG,SF']
# [u'19', u'Draymond Green (GSW)', u'SF,PF']
# [u'20', u'Kemba Walker (CHA)', u'PG']
# 20 []
# [u'22', u'Al Horford (BOS)', u'PF,C']
# [u'23', u'Victor Oladipo (IND)', u'PG,SG']
# [u'24', u'Isaiah Thomas (CLE)', u'PG']
# [u'25', u'C.J. McCollum (POR)', u'PG,SG']
# [u'26', u'LaMarcus Aldridge (SAS)', u'PF,C']
# [u'27', u'Brook Lopez (LAL)', u'C']
# [u'28', u'Klay Thompson (GSW)', u'SG,SF']
# [u'29', u'Kristaps Porzingis (NYK)', u'PF,C']
# [u'30', u'Carmelo Anthony (NYK)', u'SF,PF']
