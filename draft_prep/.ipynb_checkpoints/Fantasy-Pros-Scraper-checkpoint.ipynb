# %% [markdown]
# # Fantasy Football Prep
#
# The League I'm in has the following parameters:
# 1. 1 QB
# 2. 2 RB
# 3. 3 WR
# 4. 1 TE
# 5. 1 flex
# 6. 1 D/ST
# 7. 1 K
#
# The goal of this notebook is to provide draft-day assistance by interfacing with fantasy pro's aggregation of rankings and draft statistics.

# %%
def check_roster(open_roster,rules):
    
    
    # do a uniqueness check?
    
    pass

# %%
print np.unique(roster)
#print roster.remove('QB')
#print roster
#print roster.remove('QB')
# Out:
# ['DST' 'K' 'QB']

# %%
# boilerplate imports

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

import matplotlib as mpl
cmap = cm.gnuplot

# %%
# imports for scraping

from bs4 import BeautifulSoup

import requests

import operator

# %%
def find_best_available(position,start_point=0,des_position='QB'):
    
    indx = start_point
    filled = 0
    
    
    while (indx < len(listing)) & (filled == 0):
        
        if position[indx] == des_position:
            
            filled = 1
            
            return indx
            
        indx += 1
        

    if filled == 0:
        
        print 'out back'
        return -1

    
def calculate_snake(pos,rounds=12,teams=12):
    double = [pos,float(teams)+1.-pos]
    order = []
    for rnd in range(0,rounds,2):
        order.extend(double)
        
    return float(teams)*(np.arange(0.,float(rounds),1.)) + np.array(order)



def extract_position(pos):
    
    if sav[2][0] == 'K':
        return 'K'
    
    elif sav[2][0] == 'D':
                    
        return 'DST'
                
    elif sav[2][0] =='W':

        return 'WR'

    else:
        return sav[2][0:2]

# %% [markdown]
# ## Basic Application: Kicker Rankings

# %%
def see_rankings_position(poskey,nmax=12):

    r  = requests.get('https://www.fantasypros.com/nfl/rankings/half-point-ppr-cheatsheets.php')

    data = r.text; soup = BeautifulSoup(data); tables = soup.findAll('table')

    knum = 1

    for indx,table in enumerate(tables): 
       
        if indx==0:
                
            for row in table.find_all("tr")[2:]:
                sav = [td.get_text() for td in row.find_all("td")]
            
                try:
                    if sav[2][0] == poskey:
                    #print sav[2][0:1]
                    
                        if knum < (nmax+1):
                            print knum,sav[0],sav[1]
                        
                        knum += 1

                except:
                    pass
        

        
see_rankings_position('K',nmax=12)
# Out:
# 1 170 Justin Tucker BAL
# 2 173 Stephen Gostkowski NE
# 3 194 Dan Bailey DAL
# 4 195 Matt Bryant ATL
# 5 199 Mason Crosby GB
# 6 218 Adam Vinatieri IND
# 7 228 Steven Hauschka BUF
# 8 244 Cairo Santos KC
# 9 246 Matt Prater DET
# 10 255 Will Lutz NO
# 11 256 Brandon McManus DEN
# 12 258 Sebastian Janikowski OAK

# %%
see_rankings_position('D',nmax=12)
# Out:
# 1 139 Denver Broncos
# 2 147 Houston Texans
# 3 148 Seattle Seahawks
# 4 152 Kansas City Chiefs
# 5 157 Minnesota Vikings
# 6 159 Arizona Cardinals
# 7 168 New England Patriots
# 8 188 Carolina Panthers
# 9 193 New York Giants
# 10 203 Los Angeles Rams
# 11 209 Jacksonville Jaguars
# 12 223 Baltimore Ravens

# %% [markdown]
# These are the Kickers worth drafting in the latest rounds, do not draft anyone else!

# %%
r  = requests.get('https://www.fantasypros.com/nfl/rankings/half-point-ppr-cheatsheets.php')

# standard league
#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10


data = r.text

soup = BeautifulSoup(data)

tables = soup.findAll('table')

ordering = calculate_snake(5.,rounds=16)

ordinal = 6 # 6 in ranking
#ordinal = 8 # 8 is ADP

listing = []
player = []
position = []
notes = []
for indx,table in enumerate(tables): 
    
    #print indx,[th.get_text() for th in table.find("tr").find_all("th")]
   
    if indx==0:
        
        #print [th.get_text() for th in table.find("tr").find_all("th")]
        
        for row in table.find_all("tr")[1:]:
            sav = [td.get_text() for td in row.find_all("td")]
            # get the links here and then think about scraping those pages
            
            #try:
            #    sav2 = [td.find('a') for td in row.find_all("td")][1]
            #    print 'https://www.fantasypros.com'+sav2.get('href')
            #except:
            #    pass
            
            try:
                #if float(sav[0]) in ordering:
                #    print sav[0],sav[1],sav[2]#,sav[10]
                listing.append(float(sav[ordinal]))
                player.append(sav[1])
                position.append(extract_position(sav[2]))
                notes.append(sav[10])
                
            except:
                pass#print 'fail'
                
            
NU = np.array(listing)
PL = np.array(player)
PO = np.array(position)
NO = np.array(notes)
# organize as specified
reorg = NU.argsort()

# %%
# what should the flex position be filled with?
flex = 'WR'
bench1 = 'WR'
bench2 = 'WR'
bench3 = 'QB'
bench4 = 'RB'
bench5 = 'WR'
bench6 = 'RB'

roster = ['QB','RB','RB','WR','WR','WR','TE',flex,'DST','K',bench1,bench2,bench3,bench4,bench5,bench6]



                    
for entry,value in enumerate(NU[reorg]):
    
    if (float(entry) + 1.) in ordering:
        
        #print roster
        
        if PO[reorg[entry]] in roster:
        
            print('{0:<6.1f}{1:<24s}{2:>5s}'.format(NU[reorg[entry]],PL[reorg[entry]],PO[reorg[entry]]))
            
            roster.remove(PO[reorg[entry]])
            
            print ''
            print NO[reorg[entry]]
            print ''
            
        else:
            
            #print 'Moving to next draft slot...'
            # try to draft down the line to next position
            left_to_draft = np.unique(roster)
            
            next_bests = np.array([find_best_available(PO[reorg],entry,rospos) for rospos in left_to_draft])
            
            increase = np.min(next_bests)
            print('{0:<6.1f}{1:<24s}{2:>5s}'.format(NU[reorg[int(increase)]],PL[reorg[int(increase)]],PO[reorg[int(increase)]]))
            roster.remove(PO[reorg[int(increase)]])

            print ''
            print NO[reorg[increase]]
            print ''
            
        #print ''
        
        #print 'Next Best QB (+%i):' %(find_best_available(PO,entry+2,'QB')-(entry+2)),PL[find_best_available(PO,entry+1,'QB')]
        #print 'Next Best WR (+%i):' %(find_best_available(PO,entry+2,'WR')-(entry+2)),PL[find_best_available(PO,entry+1,'WR')]
        #print 'Next Best RB (+%i):' %(find_best_available(PO,entry+2,'RB')-(entry+2)),PL[find_best_available(PO,entry+1,'RB')]
        #print 'Next Best TE (+%i):' %(find_best_available(PO,entry+2,'TE')-(entry+2)),PL[find_best_available(PO,entry+1,'TE')]
        #print 'Next Best DST (+%i):' %(find_best_available(PO,entry+2,'DST')-(entry+2)),PL[find_best_available(PO,entry+1,'DST')]
        #print 'Next Best K (+%i):' %(find_best_available(PO,entry+2,'K')-(entry+2)),PL[find_best_available(PO,entry+1,'K')]
        #print NO[reorg[entry]]
        #print ''
        
        
        #print ''
# Out:
# 5.8   Odell Beckham Jr. NYG      WR
#
# You're nit-picking when trying to decipher between Beckham, Jones, and Brown, but the area of concern for Beckham is his newfound competition for targets. Brandon Marshall and Evan Engram are going to see targets, potentially lowering Beckham's 169 target ceiling from last year. He's talented enough to make up for the decrease, but still a tick below Jones and Brown for me.
#
# 21.8  T.Y. Hilton IND            WR
#
# Did you know that Hilton led the league in receiving yards last year? He finished with 81 more yards than Odell Beckham Jr., though he scored just six touchdowns, which is the reason he's further down draft boards. It's now four straight 1,000-yard seasons for Hilton and Andrew Luck should finally be healthy this season.
#
# 35.7  Travis Kelce KC            TE
#
# It's possible that the Chiefs finally figured out how to use Kelce, as he totaled 8.2 targets per game over the final 10 games of the season, after averaging just 5.9 targets per game over the first 38 games of his career. He finished as the No. 1 tight end while scoring just four touchdowns. There's still room to grow.
#
# 44.7  Kareem Hunt KC             RB
#
# Andy Reid always puts out a quality running game, and while Spencer Ware was the favorite to lead the team in carries, his season is now in jepordy, so Hunt could become a bellcow in a terrific scheme. Should Ware be ruled out for the season, Hunt should be drafted as high as the 3rd round.
#
# 54.7  Tyreek Hill KC             WR
#
# I can understand moving Hill up your list if you draft on upside alone, though I'm expecting massive regression with Hill. Not only did he score three special teams touchdowns, but he also scored nine rushing/receiving touchdowns on just 85 offensive touches (one every 9.4 touches). No receiver with more than 45 receptions scored a touchdown more than one every 10.1 targets in 2016, and that was Davante Adams who catches passes from Aaron Rodgers. Outside of Packers receivers, the next highest was Anquan Boldin at one every 11.9 targets. Hill is still catching passes from Alex Smith the last I checked, so I'm not betting on his crazy touchdown per touch ratio happening again.
#
# 73.0  Brandon Marshall NYG       WR
#
# If you want to take away targets from Odell Beckham Jr. in order to get Marshall into WR2 territory, you can take that venture, but I won't be on it. He's entering his age-34 season and he just came off a season where he saw 128 targets, yet finished as the No. 52 receiver. The last time someone saw more than 120 targets and finished outside the top 36 was 2014, where both Vincent Jackson and Andre Johnson accomplished that feat. They are both out of football at this point.
#
# 81.2  Devante Parker MIA         WR
#
# Here, we have the most highly hyped wideout of the preseason. He is receiving glowing praises for his off-season improvements, and now that he is with Jay Cutler, he may just live up to that potential for Miami this season.
#
# 94.9  Derek Carr OAK             QB
#
# As good as Carr looks at times, he's been very volatile as a fantasy option. Carr turned heads with his 35.8 point performance against the Buccaneers last year, but in his other 14 games, Carr was very mediocre. He totaled just 16.6 points per game in all other games, which would have ranked 17th among quarterbacks last year. His schedule is among the worst in football and they just brought in Marshawn Lynch to steal some touchdowns.
#
# 103.2 Derrick Henry TEN          RB
#
# It shouldn't shock you if Henry takes over as the lead-dog in the Titans backfield, as he's in his prime, while Murray is on the wrong side of 29. Henry averaged 4.96 yards per carry with four touchdowns over the final five weeks, while Murray averaged just 3.5 yards per carry and scored one touchdown over his final six games.
#
# 116.7 James White NE             RB
#
# The "should have been" Super Bowl MVP has been underrated this off-season, but not by the people that matter most. The Patriots extended him this off-season and paid him more than any other running back on the roster. He was the only player who finished in the top-36 last year without seeing at least 110 touches. If his role grows, as we expect it to, White should be in the running to finish as an RB2 in PPR leagues and a solid RB3 in standard leagues.
#
# 129.9 Tyrod Taylor BUF           QB
#
# Finished as the QB7 on a point per game basis in 2016, and was after finishing as the QB8 in 2015. He continues to be one of the most under-appreciated players in all of fantasy. The Bills went out and spent a high-2nd-round pick in order to snag wide receiver Zay Jones, signed free agent Anquan Boldin, and traded for Jordan Matthews. This is all negated, of course, by the fact that they traded away his true No. 1 wide receiver in Sammy Watkins. Taylor has only averaged one fewer fantasy point per game without Watkins playing, though it's not the largest of sample sizes. Losing Watkins really hurts.
#
# 145.4 Jamaal Williams GB         RB
#
# Williams is a running back built for a workhorse role, as evidenced by his seven games with 24 or more carries with BYU last year. While Ty Montgomery may be a fine converted running back, Williams was built to carry a load. Williams is a dark horse candidate to be 2017's version of Jordan Howard.
#
# 152.0 Kansas City Chiefs        DST
#
# The Chiefs continue to beat regression and force an unebelieveable amount of turnovers. Even without the most talented players, it is time to recognize that they defy normal standards.
#
# 169.3 Marqise Lee JAC            WR
#
# It's hard to argue with the Lee supporters about his 2016 campaign which netted just 32 fewer yards and three touchdowns than his teammate Allen Robinson, and that's despite seeing 46 targets less than him. Lee was actually drafted before Robinson in 2014 but hasn't been able to stay healthy, missing 9 games in his first two years. There may be something here, and if you think there is, you'll need to move Allen Robinson down your list.
#
# 176.7 Robert Woods LAR           WR
#
# He was extremely inefficient in his time with the Bills, but he did flash in a few games last season, leading the Rams to pony up some dough this offseason. It'll be interesting to see how they use him after drafting slot receiver Cooper Kupp at the start of the third round.
#
# 187.9 Mason Crosby GB             K
#
# When picking a kicker, it helps to have one with the best quarterback in the history of the NFL. Crosby should have plenty of scoring chances again this season and can hit the long field goal too.

# %%
r  = requests.get('https://www.fantasypros.com/nfl/players/tom-brady.php')

# standard league
#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10


data = r.text

soup = BeautifulSoup(data)

tables = soup.findAll('table')

for indx,table in enumerate(tables): 
    
    print indx,[th.get_text() for th in table.find("tr").find_all("th")]
    
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Rushing Stats']:
        
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Receiving Stats']:
        
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Passing Stats']:



        #print [th.get_text() for th in table.find("tr").find_all("th")]
        
    for row in table.find_all("tr")[1:]:
            sav = [td.get_text() for td in row.find_all("td")]
            
            print sav
   

# receiving
# SEASON	TEAM	GAMES	REC	TGT	YDS	Y/R	LG	TD

# rushing 
# SEASON	TEAM	GAMES	ATT	YDS	Y/A	LG	TD	FUM	FUML
# Out:
# 0 []
# 1 [u' ', u'ECR', u'Best', u'Worst', u'# of Experts']
# [u'Draft', u'QB #2', u'QB #1', u'QB #6', u'104']
# [u'Dynasty ', u'QB #10', u'QB #6', u'QB #15', u'19']
# 2 [u' ', u'Consensus', u'CBS', u'Fantrax', u'NFL', u'DW', u'FFC']
# [u'Overall', u'#18', u'#16', u'#23', u'#23', u'#27', u'#30']
# [u'Quarterbacks', u'#2', u'#2', u'#2', u'#2', u'#2', u'#2']
# 3 [u'Pass Cmp', u'Pass Att', u'Pass Yds', u'Pass Tds', u'Pass Ints', u'Rush Att', u'Rush Yds', u'Rush Tds', u'Fumbles', u'Points']
# [u'390.3', u'597.2', u'4686.2', u'35.3', u'8.1', u'35.1', u'62.3', u'1.4', u'2.9', u'321.3']
# 4 [u' ', u'Pass Yds', u'Pass Tds', u'Rush Yds', u'Rush Tds', u'Points']
# [u'Last Week', u'276', u'3', u'6', u'0', u'25.6']
# [u'Last 3 Weeks', u'226', u'2', u'1.7', u'0', u'17.9']
# [u'Season to Date', u'296.2', u'2.3', u'5.3', u'0', u'21.5']
# 5 [u' ', u'OPP', u'Pass Yds', u'Pass Tds', u'Rush Yds', u'Rush Tds', u'Points']
# [u'Week 17', u'@ MIA', u'276', u'3', u'6', u'0', u'25.6']
# [u'Week 16', u'vs. NYJ', u'214', u'3', u'0', u'0', u'20.6']
# [u'Week 15', u'@ DEN', u'188', u'0', u'-1', u'0', u'7.4']
# [u'Week 14', u'vs. BAL', u'406', u'3', u'-1', u'0', u'26.1']
# 6 [u' ', u'Opp', u'Summary']
# [u'Next Game', u'vs. KC', u'25th easiest opponent']
# [u'Next 3 Games', u'NO, HOU, CAR', u'18th easiest opponents']
# [u'Playoffs (?)', u'MIA, PIT, BUF', u'17th easiest opponents']
# [u'Rest of Season', u'--', u'16th easiest remaining opponents']
# 7 []
# 8 []
# 9 []
# 10 []
# 11 []
# [u'T-1.', u'Jason Moore', u'QB #2']
# [u'T-3.', u'Derek Lofland', u'QB #4']
# [u'T-3.', u'Justin Boone', u'QB #2']
# [u'T-3.', u'Kevin English', u'-']
# [u'View Overall Accuracy Rankings']
# 12 []
# [u'2', u"Le'Veon Bell (PIT)", u'RB']
# [u'3', u'Antonio Brown (PIT)', u'WR']
# [u'4', u'Julio Jones (ATL)', u'WR']
# [u'5', u'Odell Beckham Jr. (NYG)', u'WR']
# [u'6', u'LeSean McCoy (BUF)', u'RB']
# [u'7', u'Melvin Gordon (LAC)', u'RB']
# [u'8', u'Mike Evans (TB)', u'WR']
# [u'9', u'A.J. Green (CIN)', u'WR']
# [u'10', u'Devonta Freeman (ATL)', u'RB']
# [u'\xa0', u'View All Rankings', u'\xa0']
# 13 []
# [u'12', u'Jay Ajayi (MIA)', u'RB']
# [u'13', u'Jordan Howard (CHI)', u'RB']
# [u'14', u'DeMarco Murray (TEN)', u'RB']
# [u'15', u'Michael Thomas (NO)', u'WR']
# [u'16', u'Dez Bryant (DAL)', u'WR']
# [u'17', u'Todd Gurley (LAR)', u'RB']
# [u'18', u'T.Y. Hilton (IND)', u'WR']
# [u'19', u'Amari Cooper (OAK)', u'WR']
# [u'20', u'Doug Baldwin (SEA)', u'WR']
# 14 []
# [u'22', u'Brandin Cooks (NE)', u'WR']
# [u'23', u'Rob Gronkowski (NE)', u'TE']
# [u'24', u'Ezekiel Elliott (DAL)', u'RB']
# [u'25', u'Isaiah Crowell (CLE)', u'RB']
# [u'26', u'Lamar Miller (HOU)', u'RB']
# [u'27', u'DeAndre Hopkins (HOU)', u'WR']
# [u'28', u'Demaryius Thomas (DEN)', u'WR']
# [u'29', u'Marshawn Lynch (OAK)', u'RB']
# [u'30', u'Carlos Hyde (SF)', u'RB']
# 15 []
# [u'2', u'Paul Goldschmidt (ARI)', u'1B']
# [u'3', u'Jose Altuve (HOU)', u'2B']
# [u'4', u'Nolan Arenado (COL)', u'3B']
# [u'5', u'Charlie Blackmon (COL)', u'CF']
# [u'6', u'Giancarlo Stanton (MIA)', u'RF']
# [u'7', u'Max Scherzer (WSH)', u'SP']
# [u'8', u'Chris Sale (BOS)', u'SP']
# [u'9', u'Manny Machado (BAL)', u'3B,SS']
# [u'10', u'Joey Votto (CIN)', u'1B']
# [u'\xa0', u'View All Rankings', u'\xa0']
# 16 []
# [u'12', u'Clayton Kershaw (LAD)', u'SP']
# [u'13', u'Anthony Rizzo (CHC)', u'1B,2B']
# [u'14', u'Mookie Betts (BOS)', u'RF']
# [u'15', u'Corey Kluber (CLE)', u'SP']
# [u'16', u'Freddie Freeman (ATL)', u'1B,3B']
# [u'17', u'Corey Seager (LAD)', u'SS']
# [u'18', u'George Springer (HOU)', u'CF,RF']
# [u'19', u'Edwin Encarnacion (CLE)', u'1B,DH']
# [u'20', u'Nelson Cruz (SEA)', u'RF,DH']
# 17 []
# [u'22', u'Jose Abreu (CWS)', u'1B,DH']
# [u'23', u'Daniel Murphy (WSH)', u'1B,2B']
# [u'24', u'Miguel Cabrera (DET)', u'1B,DH']
# [u'25', u'Aaron Judge (NYY)', u'RF,DH']
# [u'26', u'Andrew McCutchen (PIT)', u'CF,RF']
# [u'27', u'Robinson Cano (SEA)', u'2B']
# [u'28', u'Josh Donaldson (TOR)', u'3B,DH']
# [u'29', u'Francisco Lindor (CLE)', u'SS']
# [u'30', u'Cody Bellinger (LAD)', u'1B,LF']
# 18 []
# [u'2', u'James Harden (HOU)', u'PG,SG']
# [u'3', u'Stephen Curry (GSW)', u'PG,SG']
# [u'4', u'Kevin Durant (GSW)', u'SF,PF']
# [u'5', u'Karl-Anthony Towns (MIN)', u'C']
# [u'6', u'Anthony Davis (NOR)', u'PF,C']
# [u'7', u'LeBron James (CLE)', u'SF,PF']
# [u'8', u'Chris Paul (HOU)', u'PG']
# [u'9', u'Kawhi Leonard (SAS)', u'SG,SF']
# [u'10', u'DeMarcus Cousins (NOR)', u'PF,C']
# [u'\xa0', u'View All Rankings', u'\xa0']
# 19 []
# [u'12', u'Paul George (OKC)', u'SF,PF']
# [u'13', u'Hassan Whiteside (MIA)', u'C,PF']
# [u'14', u'Damian Lillard (POR)', u'PG']
# [u'15', u'John Wall (WAS)', u'PG']
# [u'16', u'Kyle Lowry (TOR)', u'PG']
# [u'17', u'Paul Millsap (DEN)', u'PF,C']
# [u'18', u'Jimmy Butler (MIN)', u'SG,SF']
# [u'19', u'Draymond Green (GSW)', u'SF,PF']
# [u'20', u'Kemba Walker (CHA)', u'PG']
# 20 []
# [u'22', u'Al Horford (BOS)', u'PF,C']
# [u'23', u'Victor Oladipo (IND)', u'PG,SG']
# [u'24', u'Isaiah Thomas (CLE)', u'PG']
# [u'25', u'C.J. McCollum (POR)', u'PG,SG']
# [u'26', u'LaMarcus Aldridge (SAS)', u'PF,C']
# [u'27', u'Brook Lopez (LAL)', u'C']
# [u'28', u'Klay Thompson (GSW)', u'SG,SF']
# [u'29', u'Kristaps Porzingis (NYK)', u'PF,C']
# [u'30', u'Carmelo Anthony (NYK)', u'SF,PF']
