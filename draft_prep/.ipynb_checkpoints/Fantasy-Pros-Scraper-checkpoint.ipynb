# %% [markdown]
# # Fantasy Football Prep
#
# The League I'm in has the following parameters:
# 1. 1 QB
# 2. 2 RB
# 3. 3 WR
# 4. 1 TE
# 5. 1 flex
# 6. 1 D/ST
# 7. 1 K
#
# The goal of this notebook is to provide draft-day assistance by interfacing with fantasy pro's aggregation of rankings and draft statistics.

# %%
from IPython.display import HTML
HTML('''<script>code_show=true; function code_toggle() { if (code_show){ $('div.input').hide();} else { $('div.input').show(); } code_show = !code_show} $( document ).ready(code_toggle);</script><form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
# boilerplate imports

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

import matplotlib as mpl
cmap = cm.gnuplot

# %%
# imports for scraping

from bs4 import BeautifulSoup
import requests
import operator

# %%
def find_best_available(position,start_point=0,des_position='QB'):
    
    indx = start_point
    filled = 0
    
    
    while (indx < len(listing)) & (filled == 0):
        
        if position[indx] == des_position:
            
            filled = 1
            
            return indx
            
        indx += 1
        

    if filled == 0:
        
        print 'out back'
        return -1

    
def calculate_snake(pos,rounds=12,teams=12):
    double = [pos,float(teams)+1.-pos]
    order = []
    for rnd in range(0,rounds,2):
        order.extend(double)
        
    return float(teams)*(np.arange(0.,float(rounds),1.)) + np.array(order)



def extract_position(pos):
    
    if sav[2][0] == 'K':
        return 'K'
    
    elif sav[2][0] == 'D':
                    
        return 'DST'
                
    elif sav[2][0] =='W':

        return 'WR'

    else:
        return sav[2][0:2]

# %% [markdown]
# ## Basic Application: Kicker and Defense Rankings
#
# Kickers and Defenses are largely independent of where
#
# Rule of thumb: Don't take X defense before the X round.

# %%
def see_rankings_position(poskey,nmax=12):

    r  = requests.get('https://www.fantasypros.com/nfl/rankings/half-point-ppr-cheatsheets.php')

    r  = requests.get('https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php')


    
    data = r.text; soup = BeautifulSoup(data); tables = soup.findAll('table')

    knum = 1

    for indx,table in enumerate(tables): 
       
        if indx==0:
                
            for row in table.find_all("tr")[2:]:
                sav = [td.get_text() for td in row.find_all("td")]
            
                try:
                    if sav[2][0] == poskey:
                    #print sav[2][0:1]
                    
                        if knum < (nmax+1):
                            print knum,sav[0],sav[1]
                        
                        knum += 1

                except:
                    pass
        

        
see_rankings_position('K',nmax=12)
# Out:
# 1 170 Justin Tucker BAL
# 2 171 Stephen Gostkowski NE
# 3 182 Dan Bailey DAL
# 4 187 Matt Bryant ATL
# 5 196 Mason Crosby GB
# 6 203 Adam Vinatieri IND
# 7 223 Cairo Santos KC
# 8 227 Matt Prater DET
# 9 231 Dustin Hopkins WAS
# 10 234 Will Lutz NO
# 11 240 Steven Hauschka BUF
# 12 246 Sebastian Janikowski OAK

# %%
see_rankings_position('D',nmax=12)
# Out:
# 1 138 Denver Broncos
# 2 142 Seattle Seahawks
# 3 144 Houston Texans
# 4 149 Kansas City Chiefs
# 5 158 Minnesota Vikings
# 6 161 Arizona Cardinals
# 7 166 New England Patriots
# 8 185 Carolina Panthers
# 9 189 New York Giants
# 10 204 Jacksonville Jaguars
# 11 206 Los Angeles Rams
# 12 211 Pittsburgh Steelers

# %% [markdown]
# These are the Kickers worth drafting in the latest rounds, do not draft anyone else!

# %% [markdown]
# ## Prep the Draft Engine

# %%
r  = requests.get('https://www.fantasypros.com/nfl/rankings/half-point-ppr-cheatsheets.php')

# standard league
#r  = requests.get('https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php')


#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10


data = r.text

soup = BeautifulSoup(data)

tables = soup.findAll('table')

ordering = calculate_snake(5.,rounds=18)

ordinal = 6 # 6 in ranking
#ordinal = 8 # 8 is ADP

listing = []
player = []
position = []
notes = []
for indx,table in enumerate(tables): 
    
    #print indx,[th.get_text() for th in table.find("tr").find_all("th")]
   
    if indx==0:
        
        #print [th.get_text() for th in table.find("tr").find_all("th")]
        
        for row in table.find_all("tr")[1:]:
            sav = [td.get_text() for td in row.find_all("td")]
            # get the links here and then think about scraping those pages
            
            #try:
            #    sav2 = [td.find('a') for td in row.find_all("td")][1]
            #    print 'https://www.fantasypros.com'+sav2.get('href')
            #except:
            #    pass
            
            try:
                #if float(sav[0]) in ordering:
                #    print sav[0],sav[1],sav[2]#,sav[10]
                listing.append(float(sav[ordinal]))
                player.append(sav[1])
                position.append(extract_position(sav[2]))
                notes.append(sav[10])
                
            except:
                pass
                
            
NU = np.array(listing)
PL = np.array(player)
PO = np.array(position)
NO = np.array(notes)
# organize as specified
reorg = NU.argsort()

# %%
# make a deletable dictionary
NU2 = np.copy(NU[reorg])
PL2 = np.copy(PL[reorg])
PO2 = np.copy(PO[reorg])
NO2 = np.copy(NO[reorg])

# %%
# now set up a way to delete

drafted_list = ['David Johnson','Veon Bell',\
               'Antonio Brown','Julio Jones',\
               'Odell Beckham','Mike Evans','A.J. Green',\
               'LeSean McCoy','Melvin Gordon','Devonta Freeman',\
               'Jordy Nelson','Michael Thomas','DeMarco Murray','Ezekiel Elliott','T.Y. Hilton',\
               'Rob Gronkowski','Todd Gurley','Brandin Cooks','Dez Bryant',\
               'Doug Baldwin','Jordan Howard','Amari Cooper','Kareem Hunt','Michael Crabtree',
               'Lamar Miller','Isaiah Crowell','Leonard Fournette',\
               'Terrelle Pryor','Aaron Rodgers','DeAndre Hopkins',\
               'Demaryius Thomas','Alshon Jeffery','Carlos Hyde',\
               'Golden Tate','Ty Montgomery','Tom Brady','Marshawn Lynch','Martavis Bryant','Larry Fitzgerald',\
               'Davante Adams','Christian McCaffrey','Dalvin Cook',\
               'Drew Brees','Allen Robinson','Jarvis Landry',\
               'Russell Wilson','Stefon Diggs','Emmanuel Sanders',\
               'Travis Kelce','Bilal Powell','Greg Olsen',\
               'Joe Mixon','C.J. Anderson','Ameer Abdullah',\
               'DaVante Parker','Jordan Reed','Kelvin Benjamin',\
               'Danny Woodhead','Keenan Allen','Jamison Crowder',\
               'Tyreek Hill','Sammy Watkins','Mark Ingram','Frank Gore','Mike Gillislee','Duke Johnson','Matt Ryan','Adrian Peterson','Cam Newton','Pierre Garcon','Jimmy Graham','Parker','Chris Hogan','Theo Riddick','Tevin Coleman',\
               'Brandon Marshall','Doug Martin','Jeremy Maclin','Paul Perkins','Eric Decker','Marcus Mariota',\
               'Terrance West','Darren McFadden','Robert Kelley','DeSean Jackson','Randall Cobb','Kenny Britt','Adam Thielen','Tyler Eifert','Kyle Rudolph','Jay Ajayi',\
               'Keven White','Tyrell Williams','Zach Ertz','Derrick Henry',\
               'Delanie Walker','Ted Ginn','Mike Wallace','Seth Roberts',\
               'John Brown','Thomas Rawls','Kirk Cousins','Eddie Lacy','Donte Moncrief','Jonathan Stewart','Rishard Matthews','Matt Forte','Marvin Jones',\
               'Hunter Henry','Andrew Luck','Corey Coleman','Jameis Winston','Jacquizz Rodgers','Derek Carr','LeGarrette Blount','Eric Ebron','James White','Rex Burkhead','Seahawks','Zay Jones',\
               'Darren Sproles','Corey Davis','Dak Prescott','Willie Snead',\
               'Martellus Bennett','Jordan Matthews','Tyler Lockett','Kevin White',\
               'Marqise Lee','C.J. Prosise','Latavius Murray','Ben Roethlisberger',\
               'Chris Thompson','Coby Fleener','Jamaal Charles',\
               'Shane Vereen','Kendall Wright','Giovani Bernard',\
               'Cole Beasley','Denver','Carson Palmer',\
               'Jeremy Hill','Onta Foreman','Philip Rivers',\
            'Alvin Kamara','Houston','Robby Anderson',\
               'Jamaal Williams','Dion Lewis','Kenny Golladay',\
               'Kansas City','Cooper Kupp','Samaje Perine',\
               'Josh Doctson','Wendell Smallwood','Jack Doyle',\
               'DeAndre Washington','Charcandrick West',\
               'Minnesota','Chris Carson','Carolina','Arizona',\
               'Breshad Perriman','Justin Tucker','Devin Funchess',\
               'Sterling Shepard','Dede Westbrook','Kenny Stills',\
               'Robert Woods','Mohamed Sanu','Jalen Richard',\
               'New England','Orleans Darkwa','Angelo Henderson',\
               'Gostkowski','Cairo Santos','Jason Witten',\
               'Younghoe Koo','Andy Dalton','Taylor Gabriel',\
               'Paul Richardson','Torrey Smith','Austin Hooper',\
               'Mason Crosby','Alfred Morris','Matthew Stafford',\
               'Danny Amendola','J.J. Nelson','Matt Bryant',\
               'Dan Bailey','Chris Boswell']

for x in drafted_list:
    if np.sum(np.array([(x in val) for val in PL2]))>0.:
        w = np.where( np.array([(x in val) for val in PL2]) == True)[0]
        #print w
        NU2 = np.delete(NU2,w)
        PL2 = np.delete(PL2,w)
        PO2 = np.delete(PO2,w)
        NO2 = np.delete(NO2,w)
  

for indx,x in enumerate(PL2[0:10]):
    print indx,x


print 'Next Best QB (+%i):' %(find_best_available(PO2,2,'QB')-(2)),PL2[find_best_available(PO2,1,'QB')]
on_deck = (find_best_available(PO2,2,'QB')-(2))
print 'On Deck QB (+%i):' %(find_best_available(PO2,on_deck+3,'QB')-(2)),PL2[find_best_available(PO2,on_deck+3,'QB')]
print '----------------------------------'

print 'Next Best RB (+%i):' %(find_best_available(PO2,2,'RB')-(2)),PL2[find_best_available(PO2,1,'RB')]
on_deck = (find_best_available(PO2,2,'RB')-(2))
print 'On Deck RB (+%i):' %(find_best_available(PO2,on_deck+3,'RB')-(2)),PL2[find_best_available(PO2,on_deck+3,'RB')]
print '----------------------------------'






print 'Next Best WR (+%i):' %(find_best_available(PO2,2,'WR')-(2)),PL2[find_best_available(PO2,1,'WR')]
on_deck = (find_best_available(PO2,2,'WR')-(2))
print 'On Deck WR (+%i):' %(find_best_available(PO2,on_deck+3,'WR')-(2)),PL2[find_best_available(PO2,on_deck+3,'WR')]
print '----------------------------------'





print 'Next Best TE (+%i):' %(find_best_available(PO2,2,'TE')-(2)),PL2[find_best_available(PO2,1,'TE')]
on_deck = (find_best_available(PO2,2,'TE')-(2))
print 'On Deck TE (+%i):' %(find_best_available(PO2,on_deck+3,'TE')-(2)),PL2[find_best_available(PO2,on_deck+3,'TE')]
print '----------------------------------'
# Out:
# 0 Eli Manning NYG
#
# 1 Carson Wentz PHI
#
# 2 Tyrod Taylor BUF
#
# 3 C.J. Fiedorowicz HOU
#
# 4 Cameron Brate TB
#
# 5 Julius Thomas MIA
#
# 6 Antonio Gates LAC
#
# 7 Sam Bradford MIN
#
# 8 Joe Flacco BAL
#
# 9 Jay Cutler MIA
#
# Next Best QB (+0): Carson Wentz PHI
#
# On Deck QB (+5): Sam Bradford MIN
#
# ----------------------------------
# Next Best RB (+9): Jonathan Williams FA
#
# On Deck RB (+10): Marlon Mack IND
#
# ----------------------------------
# Next Best WR (+20): Nelson Agholor PHI
#
# On Deck WR (+27): John Ross CIN
#
# ----------------------------------
# Next Best TE (+1): C.J. Fiedorowicz HOU
#
# On Deck TE (+2): Cameron Brate TB
#
# ----------------------------------

# %%
# what should the flex position be filled with?
flex = 'WR'
bench1 = 'WR'
bench2 = 'WR'
bench3 = 'QB'
bench4 = 'RB'
bench5 = 'WR'
bench6 = 'RB'

roster = ['QB','RB','RB','WR','WR','WR','TE',\
          flex,'DST','K',\
          bench1,bench2,bench3,bench4,bench5,bench6]



                    
for entry,value in enumerate(NU[reorg]):
    
    if (float(entry) + 1.) in ordering:
        
        #print roster
        
        if PO[reorg[entry]] in roster:
        
            print('{0:<6.1f}{1:<24s}{2:>5s}'.format(NU[reorg[entry]],PL[reorg[entry]],PO[reorg[entry]]))
            
            roster.remove(PO[reorg[entry]])
            
            print ''
            print NO[reorg[entry]]
            print ''
            
        else:
            
            #print 'Moving to next draft slot...'
            # try to draft down the line to next position
            left_to_draft = np.unique(roster)
            
            next_bests = np.array([find_best_available(PO[reorg],entry,rospos) for rospos in left_to_draft])
            
            increase = np.min(next_bests)
            print('{0:<6.1f}{1:<24s}{2:>5s}'.format(NU[reorg[int(increase)]],PL[reorg[int(increase)]],PO[reorg[int(increase)]]))
            roster.remove(PO[reorg[int(increase)]])

            print ''
            print NO[reorg[increase]]
            print ''
            
        #print ''
        
        #print 'Next Best QB (+%i):' %(find_best_available(PO,entry+2,'QB')-(entry+2)),PL[find_best_available(PO,entry+1,'QB')]
        #print 'Next Best WR (+%i):' %(find_best_available(PO,entry+2,'WR')-(entry+2)),PL[find_best_available(PO,entry+1,'WR')]
        #print 'Next Best RB (+%i):' %(find_best_available(PO,entry+2,'RB')-(entry+2)),PL[find_best_available(PO,entry+1,'RB')]
        #print 'Next Best TE (+%i):' %(find_best_available(PO,entry+2,'TE')-(entry+2)),PL[find_best_available(PO,entry+1,'TE')]
        #print 'Next Best DST (+%i):' %(find_best_available(PO,entry+2,'DST')-(entry+2)),PL[find_best_available(PO,entry+1,'DST')]
        #print 'Next Best K (+%i):' %(find_best_available(PO,entry+2,'K')-(entry+2)),PL[find_best_available(PO,entry+1,'K')]
        #print NO[reorg[entry]]
        #print ''
        
        
        #print ''
# Out:
# 5.0   Odell Beckham Jr. NYG      WR
#
# You're nit-picking when trying to decipher between Beckham, Jones, and Brown, but the area of concern for Beckham is his newfound competition for targets. Brandon Marshall and Evan Engram are going to see targets, potentially lowering Beckham's 169 target ceiling from last year. He's talented enough to make up for the decrease, but still a tick below Jones and Brown for me.
#
# 20.0  Dez Bryant DAL             WR
#
# He'd be much higher on this list if he didn't have to go up against the Giants twice (held him to two catches for 18 yards on 14 targets last year), Josh Norman twice, Broncos, Cardinals, Falcons, and Seahawks. The Cowboys don't have a legit No. 2 receiver to take attention away from Bryant and now Ezekiel Elliott is suspended. It's not Bryant's fault, but he's not going to live up to his draft price this year.
#
# 29.0  Tom Brady NE               QB
#
# ...

# %%
r  = requests.get('https://www.fantasypros.com/nfl/players/tom-brady.php')

# standard league
#https://www.fantasypros.com/nfl/rankings/consensus-cheatsheets.php

# [u'Rank\r\n\r\n', u'Player (Team)', u'Pos', u'Bye', \
#         0              1              2       3
#     u'Best', u'Worst', u'Avg', u'Std Dev', u'ADP', u'vs. ADP', u'Notes']
#        4          5      6        7           8         9        10


data = r.text

soup = BeautifulSoup(data)

tables = soup.findAll('table')

for indx,table in enumerate(tables): 
    
    print indx,[th.get_text() for th in table.find("tr").find_all("th")]
    
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Rushing Stats']:
        
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Receiving Stats']:
        
    #if [th.get_text() for th in table.find("tr").find_all("th")]==[u'Passing Stats']:



        #print [th.get_text() for th in table.find("tr").find_all("th")]
        
    for row in table.find_all("tr")[1:]:
            sav = [td.get_text() for td in row.find_all("td")]
            
            print sav
   

# receiving
# SEASON	TEAM	GAMES	REC	TGT	YDS	Y/R	LG	TD

# rushing 
# SEASON	TEAM	GAMES	ATT	YDS	Y/A	LG	TD	FUM	FUML
# Out:
# 0 []
# 1 [u' ', u'ECR', u'Best', u'Worst', u'# of Experts']
# [u'Draft', u'QB #2', u'QB #1', u'QB #6', u'104']
# [u'Dynasty ', u'QB #10', u'QB #6', u'QB #15', u'19']
# 2 [u' ', u'Consensus', u'CBS', u'Fantrax', u'NFL', u'DW', u'FFC']
# [u'Overall', u'#18', u'#16', u'#23', u'#23', u'#27', u'#30']
# [u'Quarterbacks', u'#2', u'#2', u'#2', u'#2', u'#2', u'#2']
# 3 [u'Pass Cmp', u'Pass Att', u'Pass Yds', u'Pass Tds', u'Pass Ints', u'Rush Att', u'Rush Yds', u'Rush Tds', u'Fumbles', u'Points']
# [u'390.3', u'597.2', u'4686.2', u'35.3', u'8.1', u'35.1', u'62.3', u'1.4', u'2.9', u'321.3']
# 4 [u' ', u'Pass Yds', u'Pass Tds', u'Rush Yds', u'Rush Tds', u'Points']
# [u'Last Week', u'276', u'3', u'6', u'0', u'25.6']
# [u'Last 3 Weeks', u'226', u'2', u'1.7', u'0', u'17.9']
# [u'Season to Date', u'296.2', u'2.3', u'5.3', u'0', u'21.5']
# 5 [u' ', u'OPP', u'Pass Yds', u'Pass Tds', u'Rush Yds', u'Rush Tds', u'Points']
# [u'Week 17', u'@ MIA', u'276', u'3', u'6', u'0', u'25.6']
# ...

# %%
nrounds = 16.
nteams = 12.
budget = 200.
xdata = np.arange(1.,float(nrounds*nteams)+1.,1.)

# set up the curve
disp = nteams*3.

net_budget = (budget*nteams)
norm_fac = (net_budget/np.sum(np.exp(-xdata/disp)))
ydata = norm_fac * np.exp(-xdata/disp)


plt.figure(figsize=(3,2))

plt.plot(xdata,ydata)

plt.axis([20,60,00.,40.])

plt.xlabel('Pick Number',size=16)
plt.ylabel('Estimated Cost',size=16)

# %%
see_rankings_position('Q',nmax=12)
# Out:
# 1 35 Aaron Rodgers GB
# 2 39 Tom Brady NE
# 3 45 Drew Brees NO
# 4 59 Russell Wilson SEA
# 5 61 Matt Ryan ATL
# 6 76 Kirk Cousins WAS
# 7 77 Marcus Mariota TEN
# 8 82 Jameis Winston TB
# 9 86 Cam Newton CAR
# 10 91 Ben Roethlisberger PIT
# 11 92 Derek Carr OAK
# 12 95 Dak Prescott DAL
